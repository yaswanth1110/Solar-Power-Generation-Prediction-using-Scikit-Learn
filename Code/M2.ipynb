# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('GENERATION.csv')
df.head()
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# 2                            28                       7.5          0
# 3                            28                       7.5          0
# 4                            28                       7.5          0
#
#    Visibility  Relative Humidity  Average Wind Speed (Period)  \
# 0        10.0                 75                          8.0
# 1        10.0                 77                          5.0
# 2        10.0                 70                          0.0
# 3        10.0                 33                          0.0
# 4        10.0                 21                          3.0
#
#    Average Barometric Pressure (Period)  Power Generated
# 0                                 29.82                0
# 1                                 29.85                0
# 2                                 29.89             5418
# 3                                 29.91            25477
# 4                                 29.89            30069

# %%
df.columns
# Out:
# Index(['Day of Year', 'Year', 'Month', 'Day', 'First Hour of Period',
#        'Is Daylight', 'Distance to Solar Noon', 'Average Temperature (Day)',
#        'Average Wind Direction (Day)', 'Average Wind Speed (Day)', 'Sky Cover',
#        'Visibility', 'Relative Humidity', 'Average Wind Speed (Period)',
#        'Average Barometric Pressure (Period)', 'Power Generated'],
#       dtype='object')

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Relative Humidity',data=df)
# Out:
# <Axes: xlabel='Relative Humidity', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Average Wind Direction (Day)'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Distance to Solar Noon'],color='green')
# Out:
# (array([503., 301., 269., 407., 291., 312., 365., 174., 159., 139.]),
#  array([0.05040092, 0.15949695, 0.26859298, 0.37768902, 0.48678505,
#         0.59588109, 0.70497712, 0.81407315, 0.92316919, 1.03226522,
#         1.14136126]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='blue')
plt.show()

# %%
df['First Hour of Period'].hist(figsize=(10,5),color='yellow')
# Out:
# <Axes: >

# %%
sns.ecdfplot(df['Visibility'], color='orange') # scatter, plot, triplot, stackplot
# Out:
# <Axes: xlabel='Visibility', ylabel='Proportion'>

# %%
sns.kdeplot(df['Average Barometric Pressure (Period)'], color='purple')
# Out:
# <Axes: xlabel='Average Barometric Pressure (Period)', ylabel='Density'>

# %%
df['Month'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['Day'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.ecdfplot(df['Power Generated'], color='coral') # residplot, scatterplot
# Out:
# <Axes: xlabel='Power Generated', ylabel='Proportion'>

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Power Generated')
# Out:
# Power Generated
# 0        45.21
# 3         0.10
# 229       0.10
# 738       0.10
# 114       0.07
#          ...
# 12545     0.03
# 52        0.03
# 8277      0.03
# 22482     0.03
# 17257     0.03
# Name: count, Length: 1529, dtype: float64
