# %% [markdown]
# # ELASTICNET ALGORITHEM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('GENERATION.csv')

del df['Day of Year']
del df['Year']
del df['Month']
del df['Day']
del df['Is Daylight']

df.head()
# Out:
#    First Hour of Period  Distance to Solar Noon  Average Temperature (Day)  \
# 0                     1                0.859897                         69
# 1                     4                0.628535                         69
# 2                     7                0.397172                         69
# 3                    10                0.165810                         69
# 4                    13                0.065553                         69
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# 2                            28                       7.5          0
# 3                            28                       7.5          0
# 4                            28                       7.5          0
#
#    Visibility  Relative Humidity  Average Wind Speed (Period)  \
# 0        10.0                 75                          8.0
# 1        10.0                 77                          5.0
# 2        10.0                 70                          0.0
# 3        10.0                 33                          0.0
# 4        10.0                 21                          3.0
#
#    Average Barometric Pressure (Period)  Power Generated
# 0                                 29.82                0
# 1                                 29.85                0
# 2                                 29.89             5418
# 3                                 29.91            25477
# 4                                 29.89            30069

# %%
df=df.dropna()

# %%
df.columns
# Out:
# Index(['First Hour of Period', 'Distance to Solar Noon',
#        'Average Temperature (Day)', 'Average Wind Direction (Day)',
#        'Average Wind Speed (Day)', 'Sky Cover', 'Visibility',
#        'Relative Humidity', 'Average Wind Speed (Period)',
#        'Average Barometric Pressure (Period)', 'Power Generated'],
#       dtype='object')

# %%
x = df.drop(labels='Power Generated', axis=1)
y = df.loc[:,'Power Generated']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)
print("NUMBER OF TRAIN DATASET    : ", len(x_train))
print("NUMBER OF TEST DATASET      : ", len(x_test))
print("TOTAL NUMBER OF DATASET    : ", len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET    :  2335
# NUMBER OF TEST DATASET      :  584
# TOTAL NUMBER OF DATASET    :  2919

# %%
print("NUMBER OF TRAIN DATASET    : ", len(y_train))
print("NUMBER OF TEST DATASET      : ", len(y_test))
print("TOTAL NUMBER OF DATASET    : ", len(y_train)+len(y_test))
# Out:
# NUMBER OF TRAIN DATASET    :  2335
# NUMBER OF TEST DATASET      :  584
# TOTAL NUMBER OF DATASET    :  2919

# %%
from sklearn.linear_model import ElasticNet

# %%
EL = ElasticNet()
EL.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
predicted = EL.predict(x_test)

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_test,predicted)
print("THE R2 SCORE OF ELASTICNET IS :",R2*100)
# Out:
# THE R2 SCORE OF ELASTICNET IS : 33.54121838915326

# %%
from sklearn.metrics import rand_score
RAND = rand_score(y_test,predicted)
print("THE ACCURACY SCORE OF ELASTICNET IS :",RAND*100)
# Out:
# THE ACCURACY SCORE OF ELASTICNET IS : 81.56735355623958

# %%
from sklearn.metrics import explained_variance_score
EVS = explained_variance_score(y_test,predicted)
print("THE EXPLAINED VARIENCE SCORE OF ELASTICNET IS :",EVS)
# Out:
# THE EXPLAINED VARIENCE SCORE OF ELASTICNET IS : 0.3359619661222947

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test,predicted)
print("THE MEAN SQUARED ERROR SCORE OF ELASTICNET IS :",MSE)
# Out:
# THE MEAN SQUARED ERROR SCORE OF ELASTICNET IS : 73115018.13004258

# %%
from sklearn.metrics import median_absolute_error
MAE = median_absolute_error(y_test,predicted)
print("THE MEAN ABSOLUTE ERROR SCORE OF ELASTICNET IS :",MAE)
# Out:
# THE MEAN ABSOLUTE ERROR SCORE OF ELASTICNET IS : 4435.00817097164

# %%
import matplotlib.pyplot as plt
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()

# %%
import joblib
joblib.dump(EL, 'GENERATION.pkl')
# Out:
# ['GENERATION.pkl']
